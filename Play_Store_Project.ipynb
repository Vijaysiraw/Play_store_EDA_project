# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijaysiraw/Play_store_EDA_project/blob/main/Play_Store_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![play_icon.png](data:image/png;base64,...)

# %% [markdown]
# # **Project Name**    - Play Store App Review Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Name** - Vijay Singh
# ##### **Email** - skyofsiraw@gmail.com
# ##### **Contribution**    - Individual
# 1. Data Wrangling
# 2. Data Analysis
# *   what are the top apps in the dataset ?
# *   Which category is best for creating new apps?
# *   Analysis Rating, reviews and Installs
# *   Analysis paid and free apps
# *   Analysis the sentiment
# *   Analysis the sentiment polarity
# *   Analysis the sentiment subjectivity

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ##**Introduction:-**
# ####According to research, the number of mobile app downloads is increasing year over year, signaling a steady growth in demand. This growth can be attributed to the rapid rise in the number of smartphone and tablet users. As more people become comfortable with using mobile devices, the demand for mobile apps is growing. In addition, mobile app developers are finding ways to create new and innovative apps to meet the ever-growing demand for mobile content.
# ####As a result, we can expect to see an increase in the number of mobile app downloads in the coming years. This growth has the potential to open up a wide range of opportunities in the mobile industry. Companies can use this growth to create new revenue streams and to expand their customer base. Furthermore, the mobile industry will benefit from the increased competition between developers, which will lead to more apps being released with higher quality and more innovative features.
# ##**Overview:-**
# ####I selected Play Store data for our project. We have two data sets: play store data and user reviews data, where the play store data set contains Apps information like category, reviews,Rating,genres,size, installs,price, type,last update,android version,current version, and user reviews data set contain app reviews information like sentiment. Sentiment polarity and sentiment subjectivity
# ####Before beginning any kind of analysis, it is very important to observe the data set.what features we have given What is the meaning of the features? how we can use them. After a quick observation, we converted our dataset into data. frame and checked whether our data was clean or not. Our dataset is pretty much cleaner, except for some missing values in some columns. The dataset has 10841 rows and 13 columns.
# ####but in the second data set, we have 64294 rows and 5 columns. This data set contains a large number of null values, which we determined could not be filled.so we removed these null values.
# ##**Challenges:-**
# *   Except for the Rating column, the majority of the data in the Play Store is clean. The rating column has 1470 NaN values, which are approximately 14% of the entire dataset.
# *   In user reviews, the data set has 26868 rows with null values. which are approximately 42% of the entire dataset.
#
# ##**Conclusion**:-
# ####Based on the two sets of data, we were able to gather a lot of information. For example, we find that the most frequently downloaded categories are game, communication, and tool." Also, the most downloaded genres are communication, tools, and productivity. Based on this data, we can decide which category and genre are best suited for developing a new application. We can focus our efforts on the categories and genres that have been most successful in the past and use this data as a basis for decision-making when developing a new application. We can also use this data to understand which categories and genres our target audience is most likely to engage with. Ultimately, this data allows us to make more informed decisions when it comes to developing a new application. Additionally, we analyzed the very interesting fact that most of the apps in the communication category rank in the top apps, and we found that very few apps are available in this category, so we may want to consider creating new apps in this category in the future.
# ####there are certain categories that can be beneficial for success. Communication, social, and productivity are the best categories for an app. It is important to try to create a free app because 99% of users prefer free apps. After the release of the app, user reviews are very important because they provide feedback. This feedback can be used to improve the app, making it more user friendly and engaging. By taking user feedback into consideration, app developers can create an app that is truly beneficial for the user. Taking the time to listen to user feedback and make changes accordingly can be the difference between a successful app and one that fails.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# link:- https://github.com/Vijaysiraw/Play_store_EDA_project

# %% [markdown]
# #**Problem Statement**

# %% [markdown]
# Play store data
# 1. What are the most popular categories on the Google Play Store?
# 2. What are the top 10 genres in the Play Store data?
# 3. What is the ratio of paid and free apps?
# 4. Analysis of the ratings of the top 5 categories
# 5. Which age group has the most applications?
# 6. What is the average app size of paid and free apps?
# 7. How are installs affected by reviews and ratings?
# 8. what are the most popular categories in paid apps
# 9. Which price segment is most popular among paid apps?
# 10. Most downloaded paid apps and their price
# 11. Which are the top 10 apps in the Game category?
# 12. Which is the most popular genre in in game category?
# 13. What are the top 10 apps on the Google Play Store?
# 14. What is the correlation between the Play Store data?
#
#
# User review data
# 1. What is the ratio between positive and negative reviews?
# 2. What is the relation between sentiment plurality and sentiment subjectivity?
# 3. Find out which apps have the most positive and negative reviews in the dataset.
# 4. What is the sentiment polarity of the top apps?
# 5. How does sentiment polarity affect the rating?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# #### The business objective of this data is to provide app developers with the insights they need to create new apps that are both successful and profitable. Through analysis of the data, developers can discover which categories and genres are most popular, as well as which ones have the greatest potential to become successful.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Explore Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline
from importlib import reload

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
file_path='/content/drive/MyDrive/Colab Notebooks/play_store_EDA/Play Store Data.csv'
file_path2='/content/drive/MyDrive/Colab Notebooks/play_store_EDA/User Reviews.csv'

# %%
#upload play store data
play_data=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
play_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows=len(play_data.axes[0])
columns=len(play_data.axes[1])
print("Number of Rows=", rows)
print("number of Columns=", columns)
# Out:
# Number of Rows= 10841
# number of Columns= 13

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
play_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
play_data['App'].duplicated().value_counts()
# Out:
# False    9660
# True     1181
# Name: App, dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
play_data.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ####this data set contains 10841 rows and 13 columns and in additonal it contains 1181 duplicate data
# ####duplicated data-1181
# ####**Null values**
# 1.   Type :- 1 NaN value in this columns
# 2.   Content Rating :- 1 nan value in this columns
# 3.   current Ver :- 8 NaN values in this columns
# 4.   Android Var :- 3 NaN values in this columns
# 5.   Rating :- 1465 NaN values in this columns

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
play_data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe
play_data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ####we have 13 columns and these columns are:-
# * App:- Display the name of the application in this column.
# * Category:-It displays the app's category.
# * Rating:-Average rating of app(0-5)
# * Reviews:- It shows the total number of user reviews for the application.
# * Size:- It displays the application's size.
# * Installs:- It shows the total number of downloads.
# * Type:- It shows whether the app is free to use or paid.
# * Price:- It shows the price of a paid app (in dollars).
# * Content Rating: It shows which age group this application is for.
# * Genres:- It shows the genre of the application.
# * Last Updated:- It shows when the application was updated.
# * Current Ver:- It shows the current version of the application.
# * Android Ver: - It tells us about the Android version that can support the application.Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
play_data.nunique()
# Out:
# App               9660
# Category            34
# Rating              40
# Reviews           6002
# Size               462
# Installs            22
# Type                 3
# Price               93
# Content Rating       6
# Genres             120
# Last Updated      1378
# Current Ver       2832
# Android Ver         33
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ###**Data cleaning part-1**
# ####Handling NaN values and duplicate data:-
# *   When dealing with a data set, it is important to consider the presence of missing values (NaN) and duplicate data.
# *   NaN:-Missing values occur when data is not available for a certain entry
# *   Duplicate data:-same data repeat in data set

# %% [markdown]
# ####**Duplicate data:-**

# %%
#we have 1181 duplicate app in data set 
play_data['App'].duplicated().value_counts()
# Out:
# False    9660
# True     1181
# Name: App, dtype: int64

# %%
#remove duplicates data
df=play_data.drop_duplicates(subset=['App'])

# %% [markdown]
# ####**Null values:-**

# %%
#check null values in dataset
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# complete information of play store data
def info_of_data():
  info=pd.DataFrame(index=df.columns)
  info['total']=df.count()
  info['nun_value']=df.isna().sum()
  info['persent']=df.isna().mean()*100
  info['unique']=df.nunique()
  return info
info_of_data()
# Out:
#                 total  nun_value    persent  unique
# App              9660          0   0.000000    9660
# Category         9660          0   0.000000      34
# Rating           8197       1463  15.144928      40
# Reviews          9660          0   0.000000    5331
# Size             9660          0   0.000000     462
# Installs         9660          0   0.000000      22
# Type             9659          1   0.010352       3
# Price            9660          0   0.000000      93
# Content Rating   9659          1   0.010352       6
# Genres           9660          0   0.000000     119
# Last Updated     9660          0   0.000000    1378
# Current Ver      9652          8   0.082816    2818
# Android Ver      9657          3   0.031056      33

# %% [markdown]
# 1.   Type :- 1 NaN value in this columns
# 2.   Content Rating :- 1 nan value in this columns
# 3.   current Ver :- 8 NaN values in this columns
# 4.   Android Var :- 3 NaN values in this columns
# 5.   Rating :- 1465 NaN values in this columns

# %% [markdown]
# #####**1.Type,Content Rating,Current Ver,Android Var**
# #####We have 13 null values in Type,Content rating,current version, and Android var. This represents 0.12% of the total data. Therefore, we can remove these rows since they will not affect the final result.

# %%
# drop the null values  
df=df.dropna(subset=['Type','Content Rating','Current Ver','Android Ver'])

# %%
#check null values
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1458
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %% [markdown]
# #####**2.Rating data handling**
# *   The rating column has 1470 NaN values which are approximately 14% of the entire data. if we drop these rows we lose a large amount of data . which may impact the final product
# *   we fill NaN value according to installstion of apps

# %%
#check the NaN value rating in dataframe
df[df['Rating'].isna()].head()
# Out:
#                                      App        Category  Rating Reviews  \
# 23                Mcqueen Coloring pages  ART_AND_DESIGN     NaN      61
# 113            Wrinkles and rejuvenation          BEAUTY     NaN     182
# 123               Manicure - nail design          BEAUTY     NaN     119
# 126         Skin Care and Natural Beauty          BEAUTY     NaN     654
# 129  Secrets of beauty, youth and health          BEAUTY     NaN      77
#
#      Size  Installs  Type Price Content Rating  \
# 23   7.0M  100,000+  Free     0       Everyone
# 113  5.7M  100,000+  Free     0   Everyone 10+
# 123  3.7M   50,000+  Free     0       Everyone
# 126  7.4M  100,000+  Free     0           Teen
# 129  2.9M   10,000+  Free     0     Mature 17+
#
#                               Genres        Last Updated Current Ver  \
# 23   Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 113                           Beauty  September 20, 2017         8.0
# ...

# %%
#create new dataframe with no NaN values(for Rating)
clean_df=df[~df['Rating'].isna()]

# %%
#we create a dictionary that will contians the installation and avg rating data
avg_rating=dict(round(clean_df.groupby('Installs')['Rating'].mean(),1))
print(avg_rating)
# Out:
# {'1+': 5.0, '1,000+': 4.1, '1,000,000+': 4.2, '1,000,000,000+': 4.2, '10+': 4.6, '10,000+': 4.0, '10,000,000+': 4.3, '100+': 4.4, '100,000+': 4.1, '100,000,000+': 4.4, '5+': 4.6, '5,000+': 4.0, '5,000,000+': 4.2, '50+': 4.4, '50,000+': 4.0, '50,000,000+': 4.3, '500+': 4.2, '500,000+': 4.2, '500,000,000+': 4.4}

# %%
#add '0+' installation data in dictionary
avg_rating['0+']=0

# %%
#this function returns the average rating according to number of installs app
def fill_rating(x):
  return avg_rating[x]

# %%
#fill null values
df['Rating'].fillna(df['Installs'].apply(fill_rating),inplace=True)
# Out:
# <ipython-input-135-0888731935f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rating'].fillna(df['Installs'].apply(fill_rating),inplace=True)

# %%
#finally we fill the nan values in dataset
df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ####Duplicate data:-We have 1181 duplicate records in this data set, so delete this record because it is useless.
# ####NaN values:-We have a total of 1476 NaN values in this data set.13 nan values are present in the Type,Contain rating, Android ver, and current ver columns. We can remove these nan values because it's 0.1 % of the entire data set. but the Rating column has 1463 nan values, which is 14 percent of the entire data set, so we can't remove this data. So we fill the rating according to install data.

# %% [markdown]
# ###**Data cleaning part-2**

# %%
#check data type of each columns
df.dtypes.reset_index().rename(columns={'index':'Name',0:'type'})
# Out:
#               Name     type
# 0              App   object
# 1         Category   object
# 2           Rating  float64
# 3          Reviews   object
# 4             Size   object
# 5         Installs   object
# 6             Type   object
# 7            Price   object
# 8   Content Rating   object
# 9           Genres   object
# 10    Last Updated   object
# 11     Current Ver   object
# 12     Android Ver   object

# %% [markdown]
# #####We can clearly see that some of the data in this data set is not in the correct format. So we can't analyse this data, so we will clean the data and convert it into the required format.

# %% [markdown]
# ####**1.Reviews column:-**
# *   convert string data type into integer data type.

# %%
#checking data type in review column
df.loc[0,'Reviews']
# Out:
# '159'

# %%
#so we convert string data type into integer data type with help 'eval' method
df['Reviews']=df['Reviews'].apply(lambda x: eval(x))

# %%
#check data type
df['Reviews'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ####**2.Size:-**
# * The size column contains data in different units. M stands for MB, and K stands for KB. So we will convert these data to single. We will convert the data into MB.
# * MB = 1024 KB, so we must divide the value by 1024.
# * The dataset's app size is a string data type.So we will convert this data into an integer.
# * Remove unit size and convert to an integer data type.
# * We can't replace 'Varies with device' with any other value, so we will convert 'Varies with device' into a NaN' value for the data analysis.

# %%
#checking data type and data form
df['Size'].value_counts()
# Out:
# Varies with device    1226
# 12M                    181
# 11M                    181
# 13M                    177
# 14M                    176
#                       ...
# 721k                     1
# 430k                     1
# 429k                     1
# 200k                     1
# 619k                     1
# Name: Size, Length: 457, dtype: int64

# %%
from matplotlib.widgets import Ellipse
#this fuction convert 'Size' data into float data type
def convert_size_data(x):
  try:
    if 'M'==x[-1]:
      return float(x[:-1])
    elif 'K'==x[-1] or 'k'==x[-1]:
      return round(float(x[:-1])/1024,3)
    else:
      return x
  except:
    return x

# %%
#clean the data and convert float data type
df['Size']=df['Size'].apply(convert_size_data)

# %% [markdown]
# #### We know that the majority of data in the size column is 'Varies with device'. so we must replace with an appropriate value.

# %%
#check the appropriate value for this data
plt=reload(plt)
plt.figure(figsize=(10,4))
sns.histplot(x=df[df['Size']!='Varies with device']['Size'],kde=True)
# Out:
# <Axes: xlabel='Size', ylabel='Count'>

# %%
median_size=df[df['Size']!='Varies with device']['Size'].median()
mean_size=df[df['Size']!='Varies with device']['Size'].mean()
print('median of size=',median_size)
print('mean of size=',mean_size)
# Out:
# median of size= 12.0
# mean of size= 20.413555331275163

# %% [markdown]
# ####After analysing the histogram plot, we know that the maximum app size is between 10 and 15. and we also find the average and median price of app. Finally, we will fill in the median value in this data.

# %%
df.loc[df['Size']=='Varies with device','Size']=median_size

# %%
df['Size']=df['Size'].apply(lambda x: float(x))

# %%
#check data type of Size column
df['Size'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ####**3.installs column :-**
# * we can see in this column that the data is of the string data type. but we need an integer data type for calculation. So we convert this data into an integer data type.
# * we must drop the '+' and ',' signs from the data set
# * convert the str data type into int data type

# %%
#check Installs data
df['Installs'].value_counts()
# Out:
# 1,000,000+        1416
# 100,000+          1112
# 10,000+           1029
# 10,000,000+        937
# 1,000+             886
# 100+               709
# 5,000,000+         607
# 500,000+           504
# 50,000+            468
# 5,000+             467
# 10+                384
# 500+               328
# 50+                204
# 50,000,000+        202
# 100,000,000+       188
# 5+                  82
# 1+                  67
# 500,000,000+        24
# 1,000,000,000+      20
# 0+                  14
# Name: Installs, dtype: int64

# %%
#this function convert data in integer datatype
def convert_installs_data(x):
  try:
    if '+'==x[-1]:
      return int(x[:-1].replace(',',''))
    else:
      return int(x)
  except:
    return x

# %%
#convert data type of Installs column
df['Installs']=df['Installs'].apply(convert_installs_data)

# %%
 #check installs data type
print(df['Installs'].dtypes)
# Out:
# int64

# %% [markdown]
# ####**4.Price column :-**
# *   In this column, data is presented in string form and with the dollar symbol. so we must first drop the $ symbol from all the values. then we will convert the float data type.

# %%
#this function convert string price into float datatype
def convert_price_data(x):
  try:
    if '$'==x[0]:
      return float(x[1:])
    else:
      return float(x)
  except:
    return x

# %%
#convert string datatype(ex:-'$2.50') into float datatype(ex- 2.50)
df['Price']=df['Price'].apply(convert_price_data)

# %%
#chack datatype
df['Price'].dtypes
# Out:
# dtype('float64')

# %%
# finally we have clean data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   int64
#  4   Size            9648 non-null   float64
#  5   Installs        9648 non-null   int64
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   float64
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   object
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#             Rating       Reviews        Size      Installs        Price
# count  9648.000000  9.648000e+03  9648.00000  9.648000e+03  9648.000000
# mean      4.199948  2.168369e+05    19.34442  7.786211e+06     1.100193
# std       0.533206  1.832349e+06    20.59058  5.378830e+07    16.861727
# min       0.000000  0.000000e+00     0.00800  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     5.30000  1.000000e+03     0.000000
# 50%       4.300000  9.690000e+02    12.00000  1.000000e+05     0.000000
# 75%       4.500000  2.944925e+04    25.00000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07   100.00000  1.000000e+09   400.000000

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ####**1.What are the most popular categories on the Google Play Store ?**
# In this case, we discuss two major topics.
# 1. Which category has the most apps in the Play Store?
# 2. Which category has the most number of installations?

# %% [markdown]
# #####**1.Which category has the most apps in the Play Store?**

# %%
 #Number of apps in each category
find_top_category=df.groupby('Category')['App'].count()
find_top_category
# Out:
# Category
# ART_AND_DESIGN           63
# AUTO_AND_VEHICLES        85
# BEAUTY                   53
# BOOKS_AND_REFERENCE     221
# BUSINESS                420
# COMICS                   56
# COMMUNICATION           315
# DATING                  171
# EDUCATION               119
# ENTERTAINMENT           102
# EVENTS                   64
# FAMILY                 1828
# FINANCE                 345
# FOOD_AND_DRINK          112
# GAME                    959
# HEALTH_AND_FITNESS      288
# HOUSE_AND_HOME           74
# LIBRARIES_AND_DEMO       83
# LIFESTYLE               369
# MAPS_AND_NAVIGATION     131
# MEDICAL                 395
# NEWS_AND_MAGAZINES      254
# PARENTING                60
# PERSONALIZATION         374
# PHOTOGRAPHY             281
# PRODUCTIVITY            374
# SHOPPING                202
# SOCIAL                  239
# SPORTS                  325
# TOOLS                   825
# TRAVEL_AND_LOCAL        219
# VIDEO_PLAYERS           163
# ...

# %%
#we are using countplot for find number of apps available in each category
plt=reload(plt)
sns.set_style('darkgrid')
plt.figure(figsize=(15,3))
sns.countplot(x='Category', data=df)
plt.title("Number of apps per category")
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# #####2. Which category has the most number of installations?

# %%
#Number of installation in each category
installs_category=round((df.groupby(['Category'])['Installs'].sum()/1000000000).reset_index(),2)

# %%
#numbers of downloads in each category
plt=reload(plt)
plt.figure(figsize=(15,3))
sns.barplot(x='Category',y='Installs',data=installs_category)
plt.title('top category in installation')
plt.xticks(rotation=90)
plt.ylabel('Installs(billions)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose the bar plot because it allows you to calculate the frequency and sum of each category, as well as compare them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We have two plots: the first shows that the majority of the apps are in the "FAMILY," "GAME," and "TOOLS" categories. t he second chart shows that 'GAME', 'COMMUNICATION', and 'TOOLS' are the most widely installed categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# based on this data,  we can decide which category is the bast for developing new application. we can clearly see that the categories 'COMMUNICATON,' 'SOCIAL,' and 'PRODUCTIVITY' are not explored much. we can choose these categories for new application

# %% [markdown]
# ####**2.What are the top 10 genres in the play store data?**

# %%
# Chart - 2 visualization code
#sort the data according to genres
top_10_gen=round((df.groupby('Genres')['Installs'].sum()/1000000000).sort_values(ascending=False).reset_index().head(10),2)

# %%
#check the top 10 genres
top_10_gen
# Out:
#                     Genres  Installs
# 0            Communication     11.04
# 1                    Tools      7.99
# 2             Productivity      5.79
# 3                   Social      5.49
# 4              Photography      4.65
# 5  Video Players & Editors      3.92
# 6                   Arcade      3.76
# 7                   Action      3.48
# 8                   Casual      3.05
# 9            Entertainment      3.01

# %%
#check top 10 genres in play store data
plt=reload(plt)
plt.figure(figsize=(12,4))
sns.barplot(x='Genres',y='Installs',data=top_10_gen)
plt.ylabel('installs(billion)')
plt.title('installs data')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose the bar plot because it allows you to calculate the frequency and sum of each category, as well as compare them. In this plot, we want to find the top genres and compare them to each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this plot, we find out the most popular genres, and these genres are 'communication', 'tools, productivity, and many more.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Basically, this plot helps you find the best genres for your application. We can clearly see this in the 'Game' category in three of the top ten genres. and we can select other popular genres for application.

# %% [markdown]
# #### **3.What is the ratio of paid and free apps ?**

# %%
# Chart - 2 visualization code
#calculate data for pie plot
data=df['Type'].value_counts()
labels=df['Type'].unique()

# %%
#check data in pie  plot
plt=reload(plt)
plt.figure(figsize=(12,4))
plt.pie(data,labels=labels,explode=(0.2,0),autopct='%1.2f%%')
plt.title('Number of Free and Paid apps')
plt.show()

# %%
#filter out paid and free apps
apps_installs=df.groupby('Type')["Installs"].sum()
apps_installs
# Out:
# Type
# Free    75064046546
# Paid       57313871
# Name: Installs, dtype: int64

# %%
#installs data
plt=reload(plt)
plt.figure(figsize=(12,4))
plt.pie(apps_installs,labels=labels,explode=(0.2,0),autopct="%1.2f%%")
plt.title('Installs data')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose the pie chart because this chart can be used to compare data in percentage form. and we want to find out the ratio between free and paid apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We discovered that 92.20% of apps in the Google Play store are free, and the majority of apps that are installed are also free.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In this graph, we find that most users prefer free apps. We should also focus on free applications. There is a 99.92% chance that users will install a free application.This data suggests which types of apps users prefer.

# %% [markdown]
# #### **4.Analysis of the rating of the top 5 categories**

# %%
# Chart - 4 visualization code
#number of installation per category
top_category=df.groupby(['Category'])['Installs'].sum().reset_index().sort_values(by='Installs',ascending=False).head()

# %%
#list of top 5 categories
top_list=list(top_category['Category'])
top_list
# Out:
# ['GAME', 'COMMUNICATION', 'TOOLS', 'PRODUCTIVITY', 'SOCIAL']

# %%
#filter the top 5 categories data
top_category_data=df[df['Category'].isin(top_list)]

# %%
top_category_data.head()
# Out:
#                                           App       Category  Rating  \
# 335  Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 336                        WhatsApp Messenger  COMMUNICATION     4.4
# 337                         Messenger for SMS  COMMUNICATION     4.3
# 338              Google Chrome: Fast & Secure  COMMUNICATION     4.3
# 339     Messenger Lite: Free Calls & Messages  COMMUNICATION     4.4
#
#       Reviews  Size    Installs  Type  Price Content Rating         Genres  \
# 335  56642847  12.0  1000000000  Free    0.0       Everyone  Communication
# 336  69119316  12.0  1000000000  Free    0.0       Everyone  Communication
# 337    125257  17.0    10000000  Free    0.0           Teen  Communication
# 338   9642995  12.0  1000000000  Free    0.0       Everyone  Communication
# 339   1429035  12.0   100000000  Free    0.0       Everyone  Communication
#
#        Last Updated         Current Ver         Android Ver
# ...

# %%
#analysis the data in violin plot
plt=reload(plt)
plt.figure(figsize=(12,4))
sns.violinplot(x='Category',y='Rating',data=top_category_data,hue=df['Type'],split=True)
plt.title('Rating density')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose the violin plot This plot is a combination of a box plot and a KDE plot. box plot shows a summary of data sets like minimum, maximum, median, and many more. A KDE plot shows the density of the data set at the point.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this plot, we show the rating of the top 5 categories. and we also show the type of app, like free to use or paid. We can clearly see that the majority of apps have ratings around four. but in the social category, paid apps rating is not very good.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this plot, it is clear that the majority of apps have ratings above 4 stars. This indicates that the overall quality of these apps is high, and that users are generally satisfied with their experience. As a result, the focus should be on improving the rating and maintaining the app's rating.

# %% [markdown]
# #### **5.Which age group has the most applications?**

# %%
# Chart - 5 visualization code
#collect content rating data
d1=df['Content Rating'].value_counts()
l1=list(df['Content Rating'].unique())

# %%
#plot the data in pie plot
plt=reload(plt)
plt.figure(figsize=(15,5))
plt.pie(d1,labels=l1,explode=(0,0.1,0.1,0.1,0.1,1.7),autopct='%1.2f%%')
plt.title('Content Rating')
plt.show()

# %%
#number of installs
dd=df.groupby('Content Rating')['Installs'].sum()

# %%
#check the data
dd.head()
# Out:
# Content Rating
# Adults only 18+        2000000
# Everyone           52177775851
# Everyone 10+        4016271795
# Mature 17+          2437986878
# Teen               16487275393
# Name: Installs, dtype: int64

# %%
#check the percentage of each content
plt=reload(plt)
plt.figure(figsize=(15,5))
plt.pie(dd,labels=dd.index,explode=(0,0,0,0.1,0.1,2.0),autopct='%1.4f%%')
my_circle = plt.Circle( (0,0), 0.50, color='white') 
p=plt.gcf() 
p.gca().add_artist(my_circle)
plt.title('Content Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose a pie chart because it displays data in percentages and slices. We are interested in finding out what the percentage of each content rating is.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that the majority of Play Store apps are for everyone and teens.According to the second chart, the majority of users download apps for everyone and teens.
# We can see that 90% of apps are in the everyone and teens categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can clearly see that most users download everyone and 'teen' apps. In the download data, we can see that around 90% of apps download only in two categories. so we can choose these age groups for creating new apps.

# %% [markdown]
# #### **6.What is the average app size of paid and free apps?**

# %%
# Chart - 6 visualization code
#check density of app size
plt.figure(figsize=(10,4))
sns.kdeplot(x='Size',hue='Type',data=df,fill=True)
plt.title('Size of applications')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case we choose the KDE plot And KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that the majority of apps were below 20 MB. We also plot the paid user and free user in this plot.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can clearly see that the majority of apps are below 20MB. so we can consider this data when creating new apps. Sometimes, app size is also considered. In the available data, we can see that the size of both free and paid apps is below 20 MB. and we know that apps that are smaller in size require less data and space.

# %% [markdown]
# ####**7.How are Installs affected by Reviews and Rating ?**

# %%
# Chart - 7 visualization code
#check relation between rating and installs data
plt.figure(figsize=(12,4))
sns.regplot(x='Installs',y='Rating',data=df)
plt.title('Installs vs Rating data')
plt.show()

# %%
#relation between 'Installs' and 'Reviews'
plt.figure(figsize=(12,4))
sns.regplot(x=df['Reviews']/1000000,y=df['Installs']/1000000,data=df)
plt.ylabel('Installs(million)')
plt.xlabel('Reviews(million)')
plt.title('Installs vs Reviews data')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we chose two plots: a regplot and a scatter plot. Basically, the regression plot shows the relationship between two data points and also predicts the data according to the given data. A regression plot creates a line between two given parameters, and this line is the best-fit line in this data. and we want to find out the relationship between installs, ratings, and reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found out that the view and install data are correlated. When an app's reviews increase, the number of installs also increases. and we also find out that the app's rating also affects the download data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We have two plots: one shows the relation between installs and rating data, and the other shows the relation between installs and review data. We found that whenever an app's reviews increase, installs also increase. So we also focus on reviews to increase downloads. We can give the user a notification for rating. This will help you increase the download.
#
# In the installs and rating data, we can see that the data are not correlated. but we analyse the data and get some information. I have a personal opinion on this data that rating also affects installs. If you want to increase the downloads, you need to maintain the 4 and above rating. We can see that lower-rated apps have a very low probability of reaching 10 million downloads.

# %% [markdown]
# ####**8.what are the most popular categories in paid apps?**

# %%
 # Chart - 8 visualization code
paid_apps=df[df['Type']=='Paid'].groupby('Category')['Installs'].sum().sort_values(ascending=False)

# %%
#check data
paid_apps
# Out:
# Category
# GAME                   20999965
# FAMILY                 20599814
# PERSONALIZATION         3257794
# PHOTOGRAPHY             1878740
# TOOLS                   1727431
# PRODUCTIVITY            1412055
# COMMUNICATION           1360050
# SPORTS                  1243815
# LIFESTYLE               1179110
# WEATHER                  812000
# EDUCATION                602000
# MEDICAL                  560833
# HEALTH_AND_FITNESS       474110
# BUSINESS                 212775
# ENTERTAINMENT            200000
# FINANCE                  185602
# TRAVEL_AND_LOCAL         183060
# MAPS_AND_NAVIGATION      121100
# VIDEO_PLAYERS             71000
# FOOD_AND_DRINK            60000
# AUTO_AND_VEHICLES         50150
# PARENTING                 50100
# BOOKS_AND_REFERENCE       23316
# ART_AND_DESIGN            16000
# DATING                    11350
# SHOPPING                  10100
# SOCIAL                     6000
# NEWS_AND_MAGAZINES         5500
# LIBRARIES_AND_DEMO          100
# ...

# %%
#Analyse the data in pie plot
plt=reload(plt)
plt.figure(figsize=(10,10))
plt.pie(paid_apps,labels=paid_apps.index,autopct='%1.2f%%')
plt.title("top categories in paid apps")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we chose the pie plot. Pie charts are used for nominal or categorical data. A pie chart is a circle that is divided into areas, or slices. Each slice represents the count or percentage of the whole data.In this plot, we show installation data in each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this analysis, we found that the majority of apps are downloaded from games and family; around 70% are downloaded from these categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We have found that the majority of apps downloaded are from the game and family categories. This suggests that these two categories are the best for paid apps. Furthermore, the popularity of these categories indicates that there is a strong demand for these apps. As such, it is likely that developers of paid apps can expect to see a good return on investment when targeting these two categories.

# %% [markdown]
# #### **9.Which price segment is most popular among paid apps ?**

# %%
# Chart - 9 visualization code
#filter only paid apps
paid_apps=df[df['Type']=='Paid']

# %%
#check paid apps density
plt.figure(figsize=(10,4))
sns.histplot(paid_apps['Price'])
plt.title('Price of paid apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we chose the histogram. The bar plot and histogram are very similar, and both show count. but the histogram plot shows the range of data. and we also want to find out which range of data is more popular.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that the majority of paid apps prices are 0 to 15 dollars.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# With the help of this data, we can choose the price of apps. We can see that the majority of apps cost between 0 and 15 dollars. and we also found that most downloaded apps prices are in this range. So this price range is best for a new app.

# %% [markdown]
# #### **10.Most downloaded paid apps and there price**

# %%
# Chart - 9 visualization code
#sort the data in descending order and get most downloaded paid apps
top_10_paid_apps=paid_apps.sort_values(by='Installs',ascending=False).head(10)

# %%
#check top paid apps
plt.figure(figsize=(15,3))
sns.barplot(x='App',y='Price',hue=top_10_paid_apps['Installs']/1000000,data=top_10_paid_apps,palette=['red','blue'])
plt.xticks(rotation=90)
plt.title('Top paid applications in play store')
plt.ylabel('Price(in doller)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we chose the bar plot. The bar plot helps you find out the most downloaded apps and compare the data. In this plot, we are plotting the app's name, installs, and price. This plot is best for comparing these data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this plot, we found that only two apps, Hitman Sniper and Minecraft, reached the 10 million milestone. and these apps prices are 1 dollar and 7 dollars, respectively. and other apps prices are between 1 and 7 dollars.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this data, we can see that most of the apps in the top paid apps are in the game category. and we can also see that Hitman Sniper and Minecraft are the only ones that have reached the 10 million milestone, which is in the game category. So we analysed that the game category is the best for paid apps.This suggests that the game category is the most promising for app developers looking to make money.

# %% [markdown]
# #### **11.Which are the top 10 apps in the Game category ?**

# %%
# Chart - 10 visualization code
#filter out game data in dataset
top_games=df[df['Category']=='GAME'].sort_values(by='Installs',ascending=False).head(10)

# %%
top_games.head(10)
# Out:
#                                                App Category  Rating   Reviews  \
# 1654                                Subway Surfers     GAME     4.5  27722264
# 1655                              Candy Crush Saga     GAME     4.4  22426677
# 1661                                  Temple Run 2     GAME     4.3   8118609
# 1662                                           Pou     GAME     4.3  10485308
# 1722                                My Talking Tom     GAME     4.5  14891223
# 1653                                        ROBLOX     GAME     4.5   4447388
# 4052  Bike Race Free - Top Motorcycle Racing Games     GAME     4.5   2586261
# 1737                          Talking Tom Gold Run     GAME     4.6   2698348
# 1736                 Roll the Ball® - slide puzzle     GAME     4.5   1385093
# 4043                                        Vector     GAME     4.4   3058687
#
#       Size    Installs  Type  Price Content Rating  \
# 1654  76.0  1000000000  Free    0.0   Everyone 10+
# ...

# %%
#check top 10 games in dataset
plt.figure(figsize=(15,3))
sns.barplot(x='App',y=top_games['Installs']/1000000,data=top_games)
plt.ylabel('Installs(Millions)')
plt.title('Top 10 apps in game category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, choose the bar plot. This plot counts the data and compares the data for each category. In this plot, we show the top 10 games and compare the install data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Through this plot, we got the most downloaded apps and their download numbers. We found that only one app has reached the 1 billion milestone, and this app is Subway Surfers. The four apps, Candy Crush, Tample Run, Pue, and Tom, have reached the 500 million milestone. and other apps have reached 100 million

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This data provides an overview of the most downloaded apps in the game category. It reveals user interest and provides insight into which types of apps are most popular. According to the data, Subway Surfers, Temple Runs, and other similar titles have seen the highest download rates. This information can be used to inform the development of new apps, giving developers an idea of what users are looking for in terms of gaming experiences. The data may also be useful for marketing purposes, helping app creators identify and target their desired target. Ultimately, this data helps inform app creators about what types of apps have the highest potential for success.

# %% [markdown]
# #### **12.Which are the most popular  genres  in game category?**

# %%
# Chart - 12 visualization code
#filter out game data and groupby Genres data
game_data=df[df['Category']=='GAME'].groupby('Genres')['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
#top genres in game category
game_data
# Out:
#                            Genres    Installs
# 0                          Arcade  3755129155
# 1                          Action  3483039190
# 2                          Casual  2139000000
# 3                          Racing  1400247320
# 4                          Puzzle   603200000
# 5                        Strategy   457300000
# 6                          Sports   316000000
# 7                       Adventure   296695320
# 8                           Music   170120500
# 9                            Word   169172550
# 10                           Card   152826100
# 11                     Simulation   151100000
# 12                         Casino   130260700
# 13                         Trivia   128606370
# 14                          Board   112027210
# 15                   Role Playing   109100000
# 16      Casual;Action & Adventure   100000000
# 17   Adventure;Action & Adventure   100000000
# 18            Casual;Pretend Play    50000000
# ...

# %%
#check which are the most populer genre among user
plt=reload(plt)
plt.figure(figsize=(10,3))
sns.barplot(x='Genres',y=game_data['Installs']/1000000000,data=game_data.head(5))
plt.title('top 5 geners in game category')
plt.ylabel('Installs(In Billion)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we have two choices. The first is a pie plot, and the second is a bar plot. We chose a bar plot. On the basis of this plot, we are able to compare the installed data for each genre.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that the majority of apps downloaded were in the arcade and action genres. and we can also see that around 7 billion were downloaded from these genres. This data is half of the game category data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In conclusion, arcade and action genres are the best genres in the game category. This is due to their high popularity among users. If we want to develop new apps in the game category, we can choose arcade and action genres; these apps have a high chance of becoming popular among users.

# %% [markdown]
# #### **13.What are the top 10 apps on the google play store?**

# %%
# Chart - 13 visualization code
#check most download apps
df['Installs'].value_counts()
# Out:
# 1000000       1416
# 100000        1112
# 10000         1029
# 10000000       937
# 1000           886
# 100            709
# 5000000        607
# 500000         504
# 50000          468
# 5000           467
# 10             384
# 500            328
# 50             204
# 50000000       202
# 100000000      188
# 5               82
# 1               67
# 500000000       24
# 1000000000      20
# 0               14
# Name: Installs, dtype: int64

# %%
#filter 1 billion download apps
top_10_apps=df[df['Installs']==1000000000].sort_values(by='Rating',ascending=False).head(20)
top_10_apps
# Out:
#                                            App             Category  Rating  \
# 2545                                 Instagram               SOCIAL     4.5
# 2808                             Google Photos          PHOTOGRAPHY     4.5
# 1654                            Subway Surfers                 GAME     4.5
# 336                         WhatsApp Messenger        COMMUNICATION     4.4
# 3234                                    Google                TOOLS     4.4
# 3454                              Google Drive         PRODUCTIVITY     4.4
# 338               Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                      Gmail        COMMUNICATION     4.3
# 865                          Google Play Games        ENTERTAINMENT     4.3
# 3665                                   YouTube        VIDEO_PLAYERS     4.3
# 3117                 Maps - Navigate & Explore     TRAVEL_AND_LOCAL     4.3
# ...

# %%
#check rating of most download apps 
plt=reload(plt)
plt.figure(figsize=(15,3))
sns.barplot(x='App',y='Rating',data=top_10_apps)
plt.title('top 20 apps(download=1Billion)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we chose the bar plot. because it allows you to calculate the frequency and sum of each category as well as compare them. In this plot, we show the most downloaded apps in the Play Store.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that 20 apps in the Play Store reached 1 billion downloads. These apps ratings are above 3.8 or more. and the majority of apps are in the communication category.Here we can see that the majority of apps are for every age group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This data helps you find out which categories or types of apps are popular among users. From this data, we can analyse the top apps categories, types, price, content rating, and many more things. so developers can create new apps according to this data.From this plot, we can clearly see that all top apps have a good user rating, which also helps you increase downloads.

# %% [markdown]
# #### **14.What is the correlation between play store data ?**

# %%
# Chart - 14 visualization code
#correlation between data
df.corr()
# Out:
# <ipython-input-198-20217e0779c4>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.045101  0.032831  0.029916 -0.075189
# Reviews   0.045101  1.000000  0.066148  0.625158 -0.007604
# Size      0.032831  0.066148  1.000000  0.030469 -0.019592
# Installs  0.029916  0.625158  0.030469  1.000000 -0.009413
# Price    -0.075189 -0.007604 -0.019592 -0.009413  1.000000

# %%
#heatmap of play store data
plt=reload(plt)
plt.figure(figsize=(12,4))
sns.heatmap(df.corr(),annot=True)
plt.title('Heatmap of play store daata')
plt.show()
# Out:
# <ipython-input-199-ab7b260682e8>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For the relationship between numeric data in a data set, we use a heatmap plot. A heatmap is defined as a graphical representation of data using colours to visualise the value of the matrix. A positive value shows a positive correlation between data, and a negative value shows a negative correlation between data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this heatmap, we found that installs and reviews have a positive correlation, and we also observed no relation between other data in the Play Store.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This data helps you identify which data are correlated to each other. We observe that installs and reviews data are correlated, which means that when apps reviews increase, installs data also increases.With the help of this data, we can make strategies for how to increase downloads and which points are important for developing new applications.

# %% [markdown]
# ####**User Reviews data**

# %%
#upload user reviews data
user_reviews=pd.read_csv(file_path2)

# %%
#analysis user data
user_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# in this dataframe  has 64295 rows and 5 columns. The 5 columns are identified as follows:
# *   App :- Name of app
# *   Translated_Review:- User reviews
# *   Sentiment:-User views (positive, negative, and neutral)
# *   Sentiment_Polarity:-User Experience (-1 to 1), +1 means a positive review, 0 means neutral, and -1 means a negative review.
# *   Sentiment_Subjectivity :-user personal opinions (0 to 1).

# %%
#brief information user reviews data
user_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
#find out total number of null value in this dataset
user_reviews.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %% [markdown]
# we can see that we have a lot of null values.so first check can we replace null value into meaningful value.
#
#
# we have null values are:
# *   Translated_Review         26868--(42%)
# *   Sentiment                 26863--(42%)
# *   Sentiment_Polarity        26863--(42%)
# *   Sentiment_Subjectivity    26863--(42%)

# %%
#check null value tendency
user_reviews[user_reviews['Translated_Review'].isna()]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# ...

# %% [markdown]
# We can say that the apps that do not have reviews tend to have NaN values in the columns Sentiment, Sentiment_Polarity, and Sentiment_Subjectivit.
#
# We don't have efficient data with which we can fill these null values. So we drop all rows with null values, and then we analyse the data.

# %%
#we remove all null value in data set
df2=user_reviews.dropna()

# %%
#check dataset
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37427 entries, 0 to 64230
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     37427 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37427 non-null  object
#  3   Sentiment_Polarity      37427 non-null  float64
#  4   Sentiment_Subjectivity  37427 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.7+ MB

# %%
#check how many apps data in this dataset
df2['App'].value_counts()
# Out:
# Bowmasters                        312
# Helix Jump                        273
# Angry Birds Classic               273
# Calorie Counter - MyFitnessPal    254
# Duolingo: Learn Languages Free    240
#                                  ...
# Draw a Stickman: EPIC 2             1
# HD Camera                           1
# Draw In                             1
# Draw A Stickman                     1
# Best Fiends - Free Puzzle Game      1
# Name: App, Length: 865, dtype: int64

# %% [markdown]
# we can see that we have  total 865 apps data available in this dataset

# %% [markdown]
# #### **1.What is the ratio between positive and negative reviews?**

# %%
# Chart - 1 visualization code
#find out total reviews in each category
df2['Sentiment'].value_counts()
# Out:
# Positive    23998
# Negative     8271
# Neutral      5158
# Name: Sentiment, dtype: int64

# %%
#plot in pai chart
plt=reload(plt)
plt.figure(figsize=(15,5))
plt.pie(df2['Sentiment'].value_counts(),labels=df2['Sentiment'].unique(),explode=(0.1,0,0),autopct='%1.2f%%')
plt.title("Review's radio")
# Out:
# Text(0.5, 1.0, "Review's radio")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we pick a pie chart. Pie charts are used to show the relation of different parts of data to the whole. If you want to know what percentage of the data is in the total data, then we use the pie chart. we have three data in reviews data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that we have 64.12% positive, 13.78% negative, and 22.10% negative reviews in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# For the business perspective, this data is used for observation of positive and negative reviews. In this plot, we can clearly see that most users give positive reviews.

# %% [markdown]
# #### **2.what is relation between the sentiment ploarity and sentiment subjectivity ?**

# %%
# Chart - 2 visualization code
#scatter plot between 'Sentiment_Polarity' and 'Sentiment_Subjectivity'
plt=reload(plt)
plt.figure(figsize=(15,5))
sns.scatterplot(y='Sentiment_Polarity',x='Sentiment_Subjectivity',data=df2)
plt.title('sentiment polarity vs sentiment subjectivity')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we pick the scatter plot. Scatter plots are used to display the relationship between two variables. Afterward, we can examine the plot data and get some positive insight.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this plot, we found that there is no relationship between sentiment polarity and sentiment subjectivity. We observed that some time sentiment polarity and sentiment subjectivity are correlated, but the maximum time data will be different.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Sentiment polarity**:- Basically, sentiment polarity shows user reviews in numerical form. Polarity is a floating-point value in the range [-1.0 to 1.0], where +1 means very positive, 0 means neutral, and -1 means very negative.
#
# **Sentiment subjectivity**:-Sentiment and subjectivity show personal views about the application. Subjectivity is a floating-point value in the range [0.0 to 1.0], where 0.0 is very objective and 1.0 is very subjective.
#
# So we realised that these are two different things. Polarity shows the emotions of particular apps. and subjective show the personal opinion.

# %% [markdown]
# #### **3.Find out which apps have the most positive and negative reviews in the dataset**

# %%
# Chart - 3 visualization code
#count the sentiment and find out number of positive, negative and neutral reviews of each app
new=df2.groupby(['App','Sentiment'])['Sentiment'].count().unstack().rename_axis('App').reset_index()

# %%
#check the dataset
new.head()
# Out:
# Sentiment                               App  Negative  Neutral  Positive
# 0                     10 Best Foods for You      10.0     22.0     162.0
# 1          104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室       1.0      8.0      31.0
# 2                                      11st       7.0      9.0      23.0
# 3                1800 Contacts - Lens Store       6.0     10.0      64.0
# 4           1LINE – One Line with One Touch       8.0      3.0      27.0

# %%
#find out most positive and negative apps
top_positive_apps=new.sort_values(by='Positive',ascending=False).head(10)
top_negative_apps=new.sort_values(by='Negative',ascending=False).head(10)

# %%
# plot barplot and analysis the most positive and negative reviews apps
plt.figure(figsize=(10,3))
fig, ax = plt.subplots(2,1, figsize=(12,7))
sns.barplot(x='Positive',y='App',data=top_positive_apps,ax=ax[0])
sns.barplot(x='Negative',y='App',data=top_negative_apps,ax=ax[1])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we chose the bar plot. because we want to count the positive and negative reviews of each app. In this plot, we show the most positive and negative apps in the Play Store.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We have two plots: one shows the most positive reviews of apps, and the other shows the most negative reviews of apps. In the positive plot, we can see that Helix Jump has the most number of positive reviews, and in the negative plot, Angry Birds Classic has the most number of negative reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this data, we can analyse the positive and negative reviews of apps. and we can see for what reason the user is giving positive and negative reviews to an app. We can remove these shortcomings in new apps, and we can learn from existing apps in the Play Store.

# %% [markdown]
# #### **4.What is  the sentiment polarity of the top apps ?**

# %%
# Chart - 4 visualization code
#top apps
p1=df2.loc[df2['App']=='Duolingo: Learn Languages Free']
p2=df2.loc[df2['App']=='Helix Jump']
p3=df2.loc[df2['App']=='Calorie Counter - Macros']
n1=df2.loc[df2['App']=='Angry Birds Classic']
n2=df2.loc[df2['App']=='Candy Crush Saga']
n3=df2.loc[df2['App']=='8 Ball Pool']

# %%
#check polarity in strip plot
from pylab import *
fig, ax =plt.subplots(figsize=(10,6))
subplot(2,3,1)
sns.stripplot(y=p1['Sentiment_Polarity'])
plt.ylim(-1,1)
plt.xlabel('Duolingo')
subplot(2,3,2)
sns.stripplot(y=p2['Sentiment_Polarity'])
plt.ylim(-1,1)
plt.xlabel('Helix Jump')
subplot(2,3,3)
sns.stripplot(y=p3['Sentiment_Polarity'])
plt.ylim(-1,1)
plt.xlabel('Calorie Counter - Macros')
subplot(2,3,4)
sns.stripplot(y=n1['Sentiment_Polarity'])
plt.ylim(-1,1)
plt.xlabel('Angry Birds Classic')
subplot(2,3,5)
sns.stripplot(y=n2['Sentiment_Polarity'])
plt.ylim(-1,1)
plt.xlabel('Candy Crush Saga')
subplot(2,3,6)
sns.stripplot(y=n3['Sentiment_Polarity'])
plt.ylim(-1,1)
plt.xlabel('8 Ball Pool')
fig.tight_layout()
plt.show()
# Out:
# <ipython-input-216-97b748f364e0>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   subplot(2,3,1)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we want to analyse the sentiment polarity of the same apps. This data strip plot is best for analysis. The strip plot is a single-axis scatter plot that is used to visualise the distribution of many individual one-dimensional values. It is used for small data sets.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Basically, we analysed the six apps data. and we found that Helix Jump, Duolingo, and Calorie Counter-Macros had the majority of polarity above zero and angry birds, Candy Crush Saga, and 8 Ball Pool had the majority of polarity below zero.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# User behaviour data is a powerful tool for improving existing apps, as well as creating new ones. By analyzing user behaviour, developers can identify areas where an app is failing to meet user needs, and can target those areas for improvement. Additionally, user behaviour data can be used to identify innovative features that users are likely to find useful and engaging.

# %% [markdown]
# #### **5.How does sentiment polarity affect the rating?**

# %%
# Chart - 5 visualization code
#calculate the average of Sentiment polarity
avg_pol=df2.groupby('App')['Sentiment_Polarity'].mean().rename_axis('App').reset_index(name='Avg_Sentiment_Polarity')

# %%
#check the data
avg_pol.head()
# Out:
#                                 App  Avg_Sentiment_Polarity
# 0             10 Best Foods for You                0.470733
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.392405
# 2                              11st                0.185943
# 3        1800 Contacts - Lens Store                0.318145
# 4   1LINE – One Line with One Touch                0.196290

# %%
#merge play store data and user data
df3=pd.merge(df,avg_pol)

# %%
#plot the rating and sentiment polarity in regression plot
plt=reload(plt)
plt.figure(figsize=(15,5))
sns.regplot(x='Rating',y='Avg_Sentiment_Polarity',data=df3)
plt.title('Rating vs Avg_Sentiment_Polarity')
plt.show()

# %%
#correlation between data
df3.corr()
# Out:
# <ipython-input-221-75fd4920a42d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df3.corr()
#                           Rating   Reviews      Size  Installs     Price  \
# Rating                  1.000000  0.076816  0.047099  0.026817 -0.010814
# Reviews                 0.076816  1.000000  0.151962  0.466553 -0.015105
# Size                    0.047099  0.151962  1.000000  0.006657  0.011713
# Installs                0.026817  0.466553  0.006657  1.000000 -0.018925
# Price                  -0.010814 -0.015105  0.011713 -0.018925  1.000000
# Avg_Sentiment_Polarity  0.264053 -0.123308 -0.248406 -0.108549  0.023645
#
#                         Avg_Sentiment_Polarity
# Rating                                0.264053
# Reviews                              -0.123308
# Size                                 -0.248406
# ...

# %%
#heatmap
sns.heatmap(df3.corr(),annot=True)
plt.title('play store and user reviews data')
# Out:
# <ipython-input-222-c8e1b1a479d5>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df3.corr(),annot=True)
# Text(0.5, 1.0, 'play store and user reviews data')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case we pick two plot regression plot and heatmap that is used to find out what is the relation between sentiment polarity and rating.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that sentiment polarity and rating have a positive correlation. app's rating increases when sentiment polarity is positive. and we know that rating is important for increasing downloads.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the data we have gathered, we have gained some important insights. We can see how sentiment polarity affects an app's rating and downloads, which it is clear that user reviews are essential for apps. User reviews are very useful as they provide us with a lot of information about the apps, which can be used to improve them. Additionally, we can notify users when they share their experiences with us, providing us with even more data. All in all, this data has been very helpful in gaining insights, and it can be utilized to make improvements.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# If you are looking to create a new application, there are many different options to choose from. However, communication, video players, social, and productivity applications should be given priority. Focusing on free applications is the best way to go as they are easily accessible and have the potential to reach a wide audience. If you want to go for a paid application, the family and game categories should be your priority, and you should set the price below 10 dollars. Additionally, user comments should be taken into account. This is because user comments provide valuable insight into an application’s quality, performance, and user experience. By assessing user feedback, you can better ensure that your application is of a high quality, which will in turn help to ensure the success of your application.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Based on the two data sets, we were able to gather a lot of information. We can decide which categories and genres are best for developing new applications. We can focus our efforts on these categories and genres that have been most successful in the past. We can learn from the available apps in the Play Store, and then we can make a strategy for application.
#
# We should consider these points while creating a new application.
#
# *   The most downloaded categories are communication, video players, social, and productivity, but there are only a limited number of applications in these categories, so we can choose these categories.
# *   Most users prefer free applications (99.92%).
# *   The average rating of the application is four.
# *   The most popular age groups are everyone and teens.
# *   Most applications are under 20 MB in size.
# *   Installs and reviews are proportional, which means that as user reviews increase, app downloads increase as well
# *   One to ten dollars is the best price range for paid applications.
# *   Most downloaded paid apps:-Hitman sniper,Minecraft
# *   Most downloaded game app:-subway surfers
# *   Most popular genres in game category:-Arcade,Action
# *   There are 20 apps in the Play Store that have reached the 1 billion download mark.
# *   Helix Jump has the most positive ratings, and Angry Birds Classic has the most negative ratings.
# *   The sentiment polarity affects the rating, and the rating affects the number of installations.
